# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import scipy.stats as stats

lomas = pd.read_csv("s100010_LBx_12_08NOV2023.csv")

arms = pd.read_csv("subject_arms.tsv", sep="\t")
arms = arms.rename(columns={"subject_id": "SubjectID"})

lomas = pd.merge(left=lomas, right=arms, on="SubjectID", how="left")

# subset for IgG, then arms
lomas_IGG = lomas[lomas.ReportResultLabel == "IgG"].reset_index()
lomas_IGG_4 = lomas_IGG[lomas_IGG.treatment_arm == "Arm 4"].reset_index()
lomas_IGG_5 = lomas_IGG[lomas_IGG.treatment_arm == "Arm 5"].reset_index()
lomas_IGG_6 = lomas_IGG[lomas_IGG.treatment_arm == "Arm 6"].reset_index()

# subset for CRP
lomas_CRP = lomas[lomas.ReportGroupLabel == "CRP"].reset_index()

# Convert Value = "<0.03" to a number
lomas_CRP.loc[lomas_CRP["Value"] == "<0.03", ["ValueNum"]] = 0.03

# subset arms
lomas_CRP_4 = lomas_CRP[lomas_CRP.treatment_arm == "Arm 4"].reset_index()
lomas_CRP_5 = lomas_CRP[lomas_CRP.treatment_arm == "Arm 5"].reset_index()
lomas_CRP_6 = lomas_CRP[lomas_CRP.treatment_arm == "Arm 6"].reset_index()

# subest for Cytokine
lomas_Cytokine = lomas[lomas.ReportGroupLabel == "Cytokines"].reset_index()

# remove missing values based on Unit = N/A, Value = *
lomas_Cytokine = lomas_Cytokine.dropna(subset=["Unit"])
lomas_Cytokine = lomas_Cytokine[lomas_Cytokine.Value != "*"]

# convert those starting with "<" to number
lomas_Cytokine["ValueNum"] = pd.to_numeric(lomas_Cytokine["Value"].str.strip("<"))

# # subset by arms
# lomas_Cytokine_4 = lomas_Cytokine[lomas_Cytokine.treatment_arm == "Arm 4"].reset_index()
# lomas_Cytokine_5 = lomas_Cytokine[lomas_Cytokine.treatment_arm == "Arm 5"].reset_index()
# lomas_Cytokine_6 = lomas_Cytokine[lomas_Cytokine.treatment_arm == "Arm 6"].reset_index()

# %%
#20DEC23 have to subset and generate graphs for other immunoglobulins

# subset for IGA, then arms
lomas_IGA = lomas[lomas.ReportResultLabel == "IgA"]
lomas_IGA_4 = lomas_IGA[lomas_IGA.treatment_arm == "Arm 4"]
lomas_IGA_5 = lomas_IGA[lomas_IGA.treatment_arm == "Arm 5"]
lomas_IGA_6 = lomas_IGA[lomas_IGA.treatment_arm == "Arm 6"]

# subset for IGE, then arms (IU/mL)
lomas_IGE = lomas[lomas.ReportResultLabel == "IgE"]

# Convert Value = "<0.03" to a number
lomas_IGE.loc[lomas_IGE["Value"] == "<1.5", ["ValueNum"]] = 1.5

lomas_IGE_4 = lomas_IGE[lomas_IGE.treatment_arm == "Arm 4"] 
lomas_IGE_5 = lomas_IGE[lomas_IGE.treatment_arm == "Arm 5"] 
lomas_IGE_6 = lomas_IGE[lomas_IGE.treatment_arm == "Arm 6"] 

# subset for IGM, then arms (mg/dL)
lomas_IGM = lomas[lomas.ReportResultLabel == "IgM"] 
lomas_IGM_4 = lomas_IGM[lomas_IGM.treatment_arm == "Arm 4"] 
lomas_IGM_5 = lomas_IGM[lomas_IGM.treatment_arm == "Arm 5"] 
lomas_IGM_6 = lomas_IGM[lomas_IGM.treatment_arm == "Arm 6"] 

# subest for Cytokine
lomas_Cytokine = lomas[lomas.ReportGroupLabel == "Cytokines"] 

# remove missing values based on Unit = N/A, Value = *
lomas_Cytokine = lomas_Cytokine.dropna(subset=["Unit"])
lomas_Cytokine = lomas_Cytokine[lomas_Cytokine.Value != "*"]

# convert those starting with "<" to number
lomas_Cytokine["ValueNum"] = pd.to_numeric(lomas_Cytokine["Value"].str.strip("<"))

# subset for IFN-gamma, then arms (pg/mL)
lomas_IFNgamma = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IFN-gamma"] 
lomas_IFNgamma_4 = lomas_IFNgamma[lomas_IFNgamma.treatment_arm == "Arm 4"] 
lomas_IFNgamma_5 = lomas_IFNgamma[lomas_IFNgamma.treatment_arm == "Arm 5"] 
lomas_IFNgamma_6 = lomas_IFNgamma[lomas_IFNgamma.treatment_arm == "Arm 6"] 

#IL-1 beta
lomas_IL1beta = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-1 beta"] 
lomas_IL1beta_4 = lomas_IL1beta[lomas_IL1beta.treatment_arm == "Arm 4"]
lomas_IL1beta_5 = lomas_IL1beta[lomas_IL1beta.treatment_arm == "Arm 5"]
lomas_IL1beta_6 = lomas_IL1beta[lomas_IL1beta.treatment_arm == "Arm 6"]

#IL-10
lomas_IL10 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-10"] 
lomas_IL10_4 = lomas_IL10[lomas_IL10.treatment_arm == "Arm 4"]
lomas_IL10_5 = lomas_IL10[lomas_IL10.treatment_arm == "Arm 5"]
lomas_IL10_6 = lomas_IL10[lomas_IL10.treatment_arm == "Arm 6"]

#IL-12p70
lomas_IL12p70 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-12p70"] 
lomas_IL12p70_4 = lomas_IL12p70[lomas_IL12p70.treatment_arm == "Arm 4"]
lomas_IL12p70_5 = lomas_IL12p70[lomas_IL12p70.treatment_arm == "Arm 5"]
lomas_IL12p70_6 = lomas_IL12p70[lomas_IL12p70.treatment_arm == "Arm 6"]

#IL-13
lomas_IL13 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-13"] 
lomas_IL13_4 = lomas_IL13[lomas_IL13.treatment_arm == "Arm 4"]
lomas_IL13_5 = lomas_IL13[lomas_IL13.treatment_arm == "Arm 5"]
lomas_IL13_6 = lomas_IL13[lomas_IL13.treatment_arm == "Arm 6"]

#IL-2
lomas_IL2 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-2"] 
lomas_IL2_4 = lomas_IL2[lomas_IL2.treatment_arm == "Arm 4"]
lomas_IL2_5 = lomas_IL2[lomas_IL2.treatment_arm == "Arm 5"]
lomas_IL2_6 = lomas_IL2[lomas_IL2.treatment_arm == "Arm 6"]

#IL-4
lomas_IL4 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-4"] 
lomas_IL4_4 = lomas_IL4[lomas_IL4.treatment_arm == "Arm 4"]
lomas_IL4_5 = lomas_IL4[lomas_IL4.treatment_arm == "Arm 5"]
lomas_IL4_6 = lomas_IL4[lomas_IL4.treatment_arm == "Arm 6"]

#IL-6
lomas_IL6 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-6"] 
lomas_IL6_4 = lomas_IL6[lomas_IL6.treatment_arm == "Arm 4"]
lomas_IL6_5 = lomas_IL6[lomas_IL6.treatment_arm == "Arm 5"]
lomas_IL6_6 = lomas_IL6[lomas_IL6.treatment_arm == "Arm 6"]

#IL-8
lomas_IL8 = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "IL-8"] 
lomas_IL8_4 = lomas_IL8[lomas_IL8.treatment_arm == "Arm 4"]
lomas_IL8_5 = lomas_IL8[lomas_IL8.treatment_arm == "Arm 5"]
lomas_IL8_6 = lomas_IL8[lomas_IL8.treatment_arm == "Arm 6"]

#TNF-alpha
lomas_TNFA = lomas_Cytokine[lomas_Cytokine.ReportResultLabel == "TNF-alpha"] 
lomas_TNFA_4 = lomas_TNFA[lomas_TNFA.treatment_arm == "Arm 4"]
lomas_TNFA_5 = lomas_TNFA[lomas_TNFA.treatment_arm == "Arm 5"]
lomas_TNFA_6 = lomas_TNFA[lomas_TNFA.treatment_arm == "Arm 6"]

print(lomas_TNFA.ValueNum.unique())
# Out:
# [ 1.66  1.92  1.82  2.3   2.16  1.57  4.87  2.5   1.4   1.84  1.62  1.9
#   1.94  1.38  2.54  2.28  2.14  2.22  3.12  2.49  1.93  2.36  3.35  1.27
#   3.46 11.05  3.55  4.99  4.45  4.52  4.39  3.62  3.07  2.52  2.19  2.03
#   3.03  1.64  1.54  2.05  2.25  2.68  8.86  1.72  4.72  7.68  7.23  4.78
#   2.99  1.78  1.95  1.81  4.18  3.67  2.11  1.87  2.78  1.88  2.7   2.09
#   2.86  2.44  1.52  1.43  2.06  1.46  2.31  2.39  1.74  2.12  2.92  1.58
#   3.4   3.28  2.47  1.75  1.39  3.66  1.89  1.41  2.01  1.65  2.07  1.86
#   3.76  2.26  4.15  1.53]

# %%
# save all the graphs as a pdf
pdf_file_path = "SelectLomas_07DEC23.pdf"
plt.switch_backend("pdf")  # switch to pdf backend

# %%
# plotting IGG

with PdfPages(pdf_file_path, "a") as pdf:
    fig1, ax1 = plt.subplots(figsize=(8, 7))

    # plot scatter
    ax1.scatter(
        lomas_IGG_4.VisitLabel, lomas_IGG_4.ValueNum, color="orange", label="Arm 4"
    )
    ax1.scatter(
        lomas_IGG_5.VisitLabel, lomas_IGG_5.ValueNum, color="blue", label="Arm 5"
    )
    ax1.scatter(
        lomas_IGG_6.VisitLabel, lomas_IGG_6.ValueNum, color="red", label="Arm 6"
    )

    # calculate mean for each Visit
    IGG_averages4 = {}
    for visit in lomas_IGG.VisitLabel.unique():
        IGG_averages4[visit] = lomas_IGG_4[
            lomas_IGG_4.VisitLabel == visit
        ].ValueNum.mean()
    IGG_averages5 = {}
    for visit in lomas_IGG.VisitLabel.unique():
        IGG_averages5[visit] = lomas_IGG_5[
            lomas_IGG_5.VisitLabel == visit
        ].ValueNum.mean()
    IGG_averages6 = {}
    for visit in lomas_IGG.VisitLabel.unique():
        IGG_averages6[visit] = lomas_IGG_6[
            lomas_IGG_6.VisitLabel == visit
        ].ValueNum.mean()

    # plot averages
    ax1.plot(lomas_IGG_4.VisitLabel.unique(), IGG_averages4.values(), color="orange")
    ax1.plot(lomas_IGG_5.VisitLabel.unique(), IGG_averages5.values(), color="blue")
    ax1.plot(lomas_IGG_6.VisitLabel.unique(), IGG_averages6.values(), color="red")

    # plot formatting
    ax1.set_xlabel("Visit Code", fontsize=14)
    ax1.set_ylabel("Unit (mg/dL)", fontsize=16)
    ax1.set_yticks(np.arange(0, 2600, 500))
    ax1.set_title("IgG", fontsize=20)
    ax1.legend(loc="upper right")

    # save it to the pdf
    pdf.savefig(fig1, bbox_inches="tight")
    plt.close(fig1)
    print("the first graph was saved")

    # plotting CRP

    fig2, ax2 = plt.subplots(figsize=(8, 7))

    # plot scatter
    ax2.scatter(
        lomas_CRP_4.VisitLabel, lomas_CRP_4.ValueNum, color="orange", label="Arm 4"
    )
    ax2.scatter(
        lomas_CRP_5.VisitLabel, lomas_CRP_5.ValueNum, color="blue", label="Arm 5"
    )
    ax2.scatter(
        lomas_CRP_6.VisitLabel, lomas_CRP_6.ValueNum, color="red", label="Arm 6"
    )

    # calculate mean for each Visit
    CRP_averages4 = {}
    for visit in lomas_CRP.VisitLabel.unique():
        CRP_averages4[visit] = lomas_CRP_4[
            lomas_CRP_4.VisitLabel == visit
        ].ValueNum.mean()
    CRP_averages5 = {}
    for visit in lomas_CRP.VisitLabel.unique():
        CRP_averages5[visit] = lomas_CRP_5[
            lomas_CRP_5.VisitLabel == visit
        ].ValueNum.mean()
    CRP_averages6 = {}
    for visit in lomas_CRP.VisitLabel.unique():
        CRP_averages6[visit] = lomas_CRP_6[
            lomas_CRP_6.VisitLabel == visit
        ].ValueNum.mean()

    # plot averages
    ax2.plot(lomas_CRP_4.VisitLabel.unique(), CRP_averages4.values(), color="orange")
    ax2.plot(lomas_CRP_5.VisitLabel.unique(), CRP_averages5.values(), color="blue")
    ax2.plot(lomas_CRP_6.VisitLabel.unique(), CRP_averages6.values(), color="red")

    # plot formatting
    ax2.set_xlabel("Visit Code", fontsize=14)
    ax2.set_ylabel("Unit (mg/dL)", fontsize=16)
    ax2.set_yticks(np.arange(0, 14, 5))
    ax2.set_title("CRP", fontsize=20)
    ax2.legend(loc="upper right")

    pdf.savefig(fig2, bbox_inches="tight")
    plt.close(fig2)
    print("the second graph was saved")

#     fig3, ax3 = plt.subplots(figsize=(8, 7))

#     # plot scatter
#     ax3.scatter(
#         lomas_Cytokine_4.VisitLabel,
#         lomas_Cytokine_4.ValueNum,
#         color="orange",
#         label="Arm 4",
#     )
#     ax3.scatter(
#         lomas_Cytokine_5.VisitLabel,
#         lomas_Cytokine_5.ValueNum,
#         color="blue",
#         label="Arm 5",
#     )
#     ax3.scatter(
#         lomas_Cytokine_6.VisitLabel,
#         lomas_Cytokine_6.ValueNum,
#         color="red",
#         label="Arm 6",
#     )

#     # calculate mean for each Visit
#     Cytokine_averages4 = {}
#     for visit in lomas_Cytokine.VisitLabel.unique():
#         Cytokine_averages4[visit] = lomas_Cytokine_4[
#             lomas_Cytokine_4.VisitLabel == visit
#         ].ValueNum.mean()
#     Cytokine_averages5 = {}
#     for visit in lomas_Cytokine.VisitLabel.unique():
#         Cytokine_averages5[visit] = lomas_Cytokine_5[
#             lomas_Cytokine_5.VisitLabel == visit
#         ].ValueNum.mean()
#     Cytokine_averages6 = {}
#     for visit in lomas_Cytokine.VisitLabel.unique():
#         Cytokine_averages6[visit] = lomas_Cytokine_6[
#             lomas_Cytokine_6.VisitLabel == visit
#         ].ValueNum.mean()

#     # plot averages
#     ax3.plot(
#         lomas_Cytokine_4.VisitLabel.unique(),
#         Cytokine_averages4.values(),
#         color="orange",
#     )
#     ax3.plot(
#         lomas_Cytokine_5.VisitLabel.unique(), Cytokine_averages5.values(), color="blue"
#     )
#     ax3.plot(
#         lomas_Cytokine_6.VisitLabel.unique(), Cytokine_averages6.values(), color="red"
#     )

#     # plot formatting
#     ax3.set_xlabel("Visit Code", fontsize=14)
#     ax3.set_ylabel("Unit (pg/mL)", fontsize=16)
#     ax3.set_yticks(np.arange(0, 2100, 500))
#     ax3.set_title("Cytokines", fontsize=20)
#     ax3.legend(loc="upper right")

#     pdf.savefig(fig3, bbox_inches="tight")
#     plt.close(fig3)
#     pdf.close()
#     print("the third graph was saved")
# Out:
# the first graph was saved
# the second graph was saved

# %%
lomas_CRP_4.VisitNo.unique()
lomas_CRP_4
# Out:
#     level_0  index LocationID ProtocolNo  StudyNo  CenterNo  SubjectID  \
# 0         0     58        EWA   LBX-2001   100010       108     108002
# 1         1    133        EWA   LBX-2001   100010       108     108002
# 2         2    263        EWA   LBX-2001   100010       108     108002
# 3         3    393        EWA   LBX-2001   100010       108     108002
# 4         4    465        EWA   LBX-2001   100010       108     108002
# 5        10   1021        EWA   LBX-2001   100010       103     103009
# 6        11   1094        EWA   LBX-2001   100010       103     103009
# 7        12   1224        EWA   LBX-2001   100010       103     103009
# 8        13   1328        EWA   LBX-2001   100010       103     103009
# 9        14   1404        EWA   LBX-2001   100010       103     103009
# 10       40   3897        EWA   LBX-2001   100010       103     103015
# 11       41   3971        EWA   LBX-2001   100010       103     103015
# 12       42   4104        EWA   LBX-2001   100010       103     103015
# 13       43   4231        EWA   LBX-2001   100010       103     103015
# 14       44   4308        EWA   LBX-2001   100010       103     103015
# 15       50   4904        EWA   LBX-2001   100010       106     106006
# 16       51   4977        EWA   LBX-2001   100010       106     106006
# 17       52   5103        EWA   LBX-2001   100010       106     106006
# 18       53   5237        EWA   LBX-2001   100010       106     106006
# 19       54   5306        EWA   LBX-2001   100010       106     106006
# 20       55   5384        EWA   LBX-2001   100010       103     103005
# 21       56   5457        EWA   LBX-2001   100010       103     103005
# 22       57   5584        EWA   LBX-2001   100010       103     103005
# 23       58   5713        EWA   LBX-2001   100010       103     103005
# 24       59   5790        EWA   LBX-2001   100010       103     103005
# 25       89   8685        EWA   LBX-2001   100010       106     106007
# 26       90   8758        EWA   LBX-2001   100010       106     106007
# 27       91   9003        EWA   LBX-2001   100010       106     106007
# 28       92   9075        EWA   LBX-2001   100010       106     106007
# 29       97   9533        EWA   LBX-2001   100010       106     106009
# 30       98   9606        EWA   LBX-2001   100010       106     106009
# 31       99   9736        EWA   LBX-2001   100010       106     106009
# 32      100   9842        EWA   LBX-2001   100010       106     106009
# 33      101   9917        EWA   LBX-2001   100010       106     106009
# 34      117  11450        EWA   LBX-2001   100010       102     102006
# 35      118  11525        EWA   LBX-2001   100010       102     102006
# 36      119  11651        EWA   LBX-2001   100010       102     102006
# 37      120  11761        EWA   LBX-2001   100010       102     102006
# 38      121  11836        EWA   LBX-2001   100010       102     102006
# 39      123  11981        EWA   LBX-2001   100010       100     100003
# 40      124  12054        EWA   LBX-2001   100010       100     100003
# 41      125  12184        EWA   LBX-2001   100010       100     100003
# 42      126  12315        EWA   LBX-2001   100010       100     100003
# 43      127  12388        EWA   LBX-2001   100010       100     100003
# 44      128  12462        EWA   LBX-2001   100010       103     103013
# 45      129  12535        EWA   LBX-2001   100010       103     103013
# 46      130  12665        EWA   LBX-2001   100010       103     103013
# 47      131  12797        EWA   LBX-2001   100010       103     103013
# 48      132  12870        EWA   LBX-2001   100010       103     103013
# 49      143  13903        EWA   LBX-2001   100010       102     102009
# 50      144  13976        EWA   LBX-2001   100010       102     102009
# 51      145  14107        EWA   LBX-2001   100010       102     102009
# 52      146  14237        EWA   LBX-2001   100010       102     102009
# 53      147  14310        EWA   LBX-2001   100010       102     102009
#
#     ProcessNo  VisitNo VisitLabel  ...  SINormalHigh ErrorDecode  \
# 0        1006        2  Screening  ...           5.0         NaN
# 1        1006       12    Visit 2  ...           5.0         NaN
# 2        1006       32    Visit 4  ...           5.0         NaN
# 3        1006       72    Visit 7  ...           5.0         NaN
# 4        1006       82    Visit 8  ...           5.0         NaN
# 5        1008        2  Screening  ...           5.0         NaN
# 6        1008       12    Visit 2  ...           5.0         NaN
# 7        1008       32    Visit 4  ...           5.0         NaN
# 8        1008       72    Visit 7  ...           5.0         NaN
# 9        1008       82    Visit 8  ...           5.0         NaN
# 10       1015        2  Screening  ...           5.0         NaN
# 11       1015       12    Visit 2  ...           5.0         NaN
# 12       1015       32    Visit 4  ...           5.0         NaN
# 13       1015       72    Visit 7  ...           5.0         NaN
# 14       1015       82    Visit 8  ...           5.0         NaN
# 15       1017        2  Screening  ...           5.0         NaN
# 16       1017       12    Visit 2  ...           5.0         NaN
# 17       1017       32    Visit 4  ...           5.0         NaN
# 18       1017       72    Visit 7  ...           5.0         NaN
# 19       1017       82    Visit 8  ...           5.0         NaN
# 20       1018        2  Screening  ...           5.0         NaN
# 21       1018       12    Visit 2  ...           5.0         NaN
# 22       1018       32    Visit 4  ...           5.0         NaN
# 23       1018       72    Visit 7  ...           5.0         NaN
# 24       1018       82    Visit 8  ...           5.0         NaN
# 25       1037        2  Screening  ...           5.0         NaN
# 26       1037       12    Visit 2  ...           5.0         NaN
# 27       1037       72    Visit 7  ...           5.0         NaN
# 28       1037       82    Visit 8  ...           5.0         NaN
# 29       1039        2  Screening  ...           5.0         NaN
# 30       1039       12    Visit 2  ...           5.0         NaN
# 31       1039       32    Visit 4  ...           5.0         NaN
# 32       1039       72    Visit 7  ...           5.0         NaN
# 33       1039       82    Visit 8  ...           5.0         NaN
# 34       1048        2  Screening  ...           5.0         NaN
# 35       1048       12    Visit 2  ...           5.0         NaN
# 36       1048       32    Visit 4  ...           5.0         NaN
# 37       1048       72    Visit 7  ...           5.0         NaN
# 38       1048       82    Visit 8  ...           5.0         NaN
# 39       1052        2  Screening  ...           5.0         NaN
# 40       1052       12    Visit 2  ...           5.0         NaN
# 41       1052       32    Visit 4  ...           5.0         NaN
# 42       1052       72    Visit 7  ...           5.0         NaN
# 43       1052       82    Visit 8  ...           5.0         NaN
# 44       1053        2  Screening  ...           5.0         NaN
# 45       1053       12    Visit 2  ...           5.0         NaN
# 46       1053       32    Visit 4  ...           5.0         NaN
# 47       1053       72    Visit 7  ...           5.0         NaN
# 48       1053       82    Visit 8  ...           5.0         NaN
# 49       1061        2  Screening  ...           5.0         NaN
# 50       1061       12    Visit 2  ...           5.0         NaN
# 51       1061       32    Visit 4  ...           5.0         NaN
# 52       1061       72    Visit 7  ...           5.0         NaN
# 53       1061       82    Visit 8  ...           5.0         NaN
#
#               AnalyseDateTime  AlertStatus    MaterialScannedDateTime  \
# 0   2023-05-11T19:10:00-04:00          NaN  2023-05-10T18:13:35-04:00
# 1   2023-05-11T19:10:00-04:00          NaN  2023-05-10T18:14:00-04:00
# 2   2023-05-11T19:10:00-04:00          NaN  2023-05-10T18:13:11-04:00
# 3   2023-05-18T20:39:00-04:00          NaN  2023-05-17T16:49:04-04:00
# 4   2023-05-31T22:11:00-04:00          NaN  2023-05-31T13:39:48-04:00
# 5   2023-06-06T22:12:00-04:00          NaN  2023-06-06T14:27:43-04:00
# 6   2023-06-08T21:09:00-04:00          NaN  2023-06-07T19:45:33-04:00
# 7   2023-06-09T22:48:00-04:00          NaN  2023-06-09T13:04:56-04:00
# 8   2023-06-15T21:23:00-04:00          NaN  2023-06-15T13:44:05-04:00
# 9   2023-07-08T00:37:00-04:00          NaN  2023-07-07T16:45:15-04:00
# 10  2023-08-25T01:14:00-04:00          NaN  2023-08-24T16:44:12-04:00
# 11  2023-08-26T03:15:00-04:00          NaN  2023-08-25T17:24:10-04:00
# 12  2023-08-30T23:58:00-04:00          NaN  2023-08-30T16:14:18-04:00
# 13  2023-09-05T23:09:00-04:00          NaN  2023-09-05T14:45:27-04:00
# 14  2023-09-26T23:35:00-04:00          NaN  2023-09-26T15:16:42-04:00
# 15  2023-06-29T18:30:00-04:00          NaN  2023-06-28T17:06:23-04:00
# 16  2023-06-29T18:55:00-04:00          NaN  2023-06-28T17:06:42-04:00
# 17  2023-07-07T21:29:00-04:00          NaN  2023-07-07T13:54:30-04:00
# 18  2023-07-07T18:02:00-04:00          NaN  2023-07-06T17:00:30-04:00
# 19  2023-08-04T02:20:00-04:00          NaN  2023-08-03T16:08:24-04:00
# 20  2023-04-11T22:35:00-04:00          NaN  2023-04-11T15:24:08-04:00
# 21  2023-06-15T00:03:00-04:00          NaN  2023-06-14T08:25:53-04:00
# 22  2023-04-11T22:35:00-04:00          NaN  2023-04-11T15:24:02-04:00
# 23  2023-04-17T22:11:00-04:00          NaN  2023-04-17T12:42:20-04:00
# 24  2023-05-09T22:08:00-04:00          NaN  2023-05-09T14:41:53-04:00
# 25  2023-07-13T23:32:00-04:00          NaN  2023-07-13T08:40:24-04:00
# 26  2023-07-13T23:32:00-04:00          NaN  2023-07-13T08:40:36-04:00
# 27  2023-07-13T23:32:00-04:00          NaN  2023-07-13T08:35:50-04:00
# 28  2023-08-04T21:10:00-04:00          NaN  2023-08-03T16:08:19-04:00
# 29  2023-07-15T22:08:00-04:00          NaN  2023-07-15T13:42:25-04:00
# 30  2023-07-15T19:20:00-04:00          NaN  2023-07-14T16:35:54-04:00
# 31  2023-07-19T23:34:00-04:00          NaN  2023-07-19T15:54:50-04:00
# 32  2023-07-26T21:46:00-04:00          NaN  2023-07-25T16:18:59-04:00
# 33  2023-08-17T22:45:00-04:00          NaN  2023-08-17T13:51:07-04:00
# 34  2023-07-26T21:46:00-04:00          NaN  2023-07-25T16:18:25-04:00
# 35  2023-07-27T19:51:00-04:00          NaN  2023-07-26T15:42:20-04:00
# 36  2023-07-29T21:31:00-04:00          NaN  2023-07-28T15:39:33-04:00
# 37  2023-08-05T19:55:00-04:00          NaN  2023-08-04T16:56:43-04:00
# 38  2023-08-30T00:05:00-04:00          NaN  2023-08-29T15:34:13-04:00
# 39  2023-08-16T20:37:00-04:00          NaN  2023-08-15T15:19:33-04:00
# 40  2023-08-17T20:27:00-04:00          NaN  2023-08-16T15:57:18-04:00
# 41  2023-08-19T20:07:00-04:00          NaN  2023-08-18T16:36:19-04:00
# 42  2023-08-25T01:14:00-04:00          NaN  2023-08-24T16:45:19-04:00
# 43  2023-09-16T19:24:00-04:00          NaN  2023-09-15T16:05:01-04:00
# 44  2023-08-16T23:45:00-04:00          NaN  2023-08-16T15:57:38-04:00
# 45  2023-08-19T21:43:00-04:00          NaN  2023-08-19T14:24:33-04:00
# 46  2023-08-19T21:43:00-04:00          NaN  2023-08-19T14:24:27-04:00
# 47  2023-08-26T03:43:00-04:00          NaN  2023-08-25T17:23:10-04:00
# 48  2023-09-21T23:17:00-04:00          NaN  2023-09-20T16:53:56-04:00
# 49  2023-08-30T21:00:00-04:00          NaN  2023-08-30T14:04:25-04:00
# 50  2023-08-31T19:23:00-04:00          NaN  2023-08-30T16:15:04-04:00
# 51  2023-09-02T00:39:00-04:00          NaN  2023-09-01T16:31:20-04:00
# 52  2023-10-30T19:38:00-04:00          NaN  2023-10-30T10:07:37-04:00
# 53  2023-09-30T00:13:00-04:00          NaN  2023-09-29T16:09:43-04:00
#
#     PartsampleBarcode treatment_arm      treatment_arm_description  \
# 0       1360259306611         Arm 4  High dose IV bolus + IU + Abx
# 1       1360259308611         Arm 4  High dose IV bolus + IU + Abx
# 2       1360259303611         Arm 4  High dose IV bolus + IU + Abx
# 3       1360260548611         Arm 4  High dose IV bolus + IU + Abx
# 4       1360262806611         Arm 4  High dose IV bolus + IU + Abx
# 5       1360264546611         Arm 4  High dose IV bolus + IU + Abx
# 6       1360264804611         Arm 4  High dose IV bolus + IU + Abx
# 7       1360265663611         Arm 4  High dose IV bolus + IU + Abx
# 8       1360267064611         Arm 4  High dose IV bolus + IU + Abx
# 9       1360273225611         Arm 4  High dose IV bolus + IU + Abx
# 10      1360286659611         Arm 4  High dose IV bolus + IU + Abx
# 11      1360287003611         Arm 4  High dose IV bolus + IU + Abx
# 12      1360288288611         Arm 4  High dose IV bolus + IU + Abx
# 13      1360289608611         Arm 4  High dose IV bolus + IU + Abx
# 14      1360296910611         Arm 4  High dose IV bolus + IU + Abx
# 15      1360270832611         Arm 4  High dose IV bolus + IU + Abx
# 16      1360270828611         Arm 4  High dose IV bolus + IU + Abx
# 17      1360273162611         Arm 4  High dose IV bolus + IU + Abx
# 18      1360272676611         Arm 4  High dose IV bolus + IU + Abx
# 19      1360280434611         Arm 4  High dose IV bolus + IU + Abx
# 20      1360254109611         Arm 4  High dose IV bolus + IU + Abx
# 21      1360266505611         Arm 4  High dose IV bolus + IU + Abx
# 22      1360254107611         Arm 4  High dose IV bolus + IU + Abx
# 23      1360255072611         Arm 4  High dose IV bolus + IU + Abx
# 24      1360259016611         Arm 4  High dose IV bolus + IU + Abx
# 25      1360274574611         Arm 4  High dose IV bolus + IU + Abx
# 26      1360274575611         Arm 4  High dose IV bolus + IU + Abx
# 27      1360274572611         Arm 4  High dose IV bolus + IU + Abx
# 28      1360280433611         Arm 4  High dose IV bolus + IU + Abx
# 29      1360275635611         Arm 4  High dose IV bolus + IU + Abx
# 30      1360275261611         Arm 4  High dose IV bolus + IU + Abx
# 31      1360276335611         Arm 4  High dose IV bolus + IU + Abx
# 32      1360277752611         Arm 4  High dose IV bolus + IU + Abx
# 33      1360284262611         Arm 4  High dose IV bolus + IU + Abx
# 34      1360277755611         Arm 4  High dose IV bolus + IU + Abx
# 35      1360278405611         Arm 4  High dose IV bolus + IU + Abx
# 36      1360279088611         Arm 4  High dose IV bolus + IU + Abx
# 37      1360280824611         Arm 4  High dose IV bolus + IU + Abx
# 38      1360287790611         Arm 4  High dose IV bolus + IU + Abx
# 39      1360283353611         Arm 4  High dose IV bolus + IU + Abx
# 40      1360283796611         Arm 4  High dose IV bolus + IU + Abx
# 41      1360284819611         Arm 4  High dose IV bolus + IU + Abx
# 42      1360286583611         Arm 4  High dose IV bolus + IU + Abx
# 43      1360293526611         Arm 4  High dose IV bolus + IU + Abx
# 44      1360283799611         Arm 4  High dose IV bolus + IU + Abx
# 45      1360285274611         Arm 4  High dose IV bolus + IU + Abx
# 46      1360285272611         Arm 4  High dose IV bolus + IU + Abx
# 47      1360287005611         Arm 4  High dose IV bolus + IU + Abx
# 48      1360294949611         Arm 4  High dose IV bolus + IU + Abx
# 49      1360288220611         Arm 4  High dose IV bolus + IU + Abx
# 50      1360288331611         Arm 4  High dose IV bolus + IU + Abx
# 51      1360289175611         Arm 4  High dose IV bolus + IU + Abx
# 52      1360308537611         Arm 4  High dose IV bolus + IU + Abx
# 53      1360298409611         Arm 4  High dose IV bolus + IU + Abx
#
#    protocol_version subversion
# 0         Version 2        2.0
# 1         Version 2        2.0
# 2         Version 2        2.0
# 3         Version 2        2.0
# 4         Version 2        2.0
# 5         Version 2        2.0
# 6         Version 2        2.0
# 7         Version 2        2.0
# 8         Version 2        2.0
# 9         Version 2        2.0
# 10        Version 2        2.0
# 11        Version 2        2.0
# 12        Version 2        2.0
# 13        Version 2        2.0
# 14        Version 2        2.0
# 15        Version 2        2.0
# 16        Version 2        2.0
# 17        Version 2        2.0
# 18        Version 2        2.0
# 19        Version 2        2.0
# 20        Version 2        2.0
# 21        Version 2        2.0
# 22        Version 2        2.0
# 23        Version 2        2.0
# 24        Version 2        2.0
# 25        Version 2        2.0
# 26        Version 2        2.0
# 27        Version 2        2.0
# 28        Version 2        2.0
# 29        Version 2        2.0
# 30        Version 2        2.0
# 31        Version 2        2.0
# 32        Version 2        2.0
# 33        Version 2        2.0
# 34        Version 2        2.0
# 35        Version 2        2.0
# 36        Version 2        2.0
# 37        Version 2        2.0
# 38        Version 2        2.0
# 39        Version 2        2.0
# 40        Version 2        2.0
# 41        Version 2        2.0
# 42        Version 2        2.0
# 43        Version 2        2.0
# 44        Version 2        2.0
# 45        Version 2        2.0
# 46        Version 2        2.0
# 47        Version 2        2.0
# 48        Version 2        2.0
# 49        Version 2        2.0
# 50        Version 2        2.0
# 51        Version 2        2.0
# 52        Version 2        2.0
# 53        Version 2        2.0
#
# [54 rows x 43 columns]

# %%
plt.figure(figsize=(8, 7))

# plot scatter
plt.scatter(lomas_IGG_4.VisitLabel, lomas_IGG_4.ValueNum, color="#D55e00", label="Arm A IU + 0.1x IV Bolus")
plt.scatter(lomas_IGG_5.VisitLabel, lomas_IGG_5.ValueNum, color="#0072B2", label="Arm B IU + 0.01x IV Bolus")
plt.scatter(lomas_IGG_6.VisitLabel, lomas_IGG_6.ValueNum, color="#B07AA1", label="Arm C IU + 1x IV Infusion")

# # calculate mean for each Visit
IGG_averages4 = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG_averages4[visit] = lomas_IGG_4[
        lomas_IGG_4.VisitLabel == visit
    ].ValueNum.mean()
IGG_averages5 = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG_averages5[visit] = lomas_IGG_5[
        lomas_IGG_5.VisitLabel == visit
    ].ValueNum.mean()
IGG_averages6 = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG_averages6[visit] = lomas_IGG_6[
        lomas_IGG_6.VisitLabel == visit
    ].ValueNum.mean()

# # plot averages
plt.plot(lomas_IGG_4.VisitLabel.unique(), IGG_averages4.values(), color="#D55e00")
plt.plot(lomas_IGG_5.VisitLabel.unique(), IGG_averages5.values(), color="#0072B2")
plt.plot(lomas_IGG_6.VisitLabel.unique(), IGG_averages6.values(), color="#B07AA1")

# plot formatting
plt.ylim(-50, 2500) # Set y-axis limits
plt.xlabel("Timepoints", fontsize=14)
new_x_ticks = ['Day 1', 'Day 2', 'Day 4', 'Day 10', 'Day 34']
plt.xticks(lomas_IGG_4.VisitLabel.unique(), new_x_ticks)
plt.ylabel("Unit (mg/dL)", fontsize=16)
# plt.yticks(np.arange(0, 2600, 500))
plt.title("IgG", fontsize=20)
plt.legend(loc="right", fontsize=20, markerscale=2.0, bbox_to_anchor=(1.9,.5) )

# save it to the pdf
plt.savefig("IgG.svg", format='svg', bbox_inches='tight')

plt.show()

plt.close('all')

# %% [markdown]
# ## Get stuff as Dictionaries

# %%
#additional dictionaries
TNFA4_visit_dict = {}
for visit in lomas_TNFA.VisitLabel.unique():
    TNFA4_visit_dict[visit] = lomas_TNFA_4[
        lomas_TNFA_4.VisitLabel == visit
    ].ValueNum
    
TNFA5_visit_dict = {}
for visit in lomas_TNFA.VisitLabel.unique():
    TNFA5_visit_dict[visit] = lomas_TNFA_5[
        lomas_TNFA_5.VisitLabel == visit
    ].ValueNum
    
TNFA6_visit_dict = {}
for visit in lomas_TNFA.VisitLabel.unique():
    TNFA6_visit_dict[visit] = lomas_TNFA_6[
        lomas_TNFA_6.VisitLabel == visit
    ].ValueNum
    
for visit in lomas_TNFA.VisitLabel.unique():
    statistic, p_value = stats.f_oneway(TNFA4_visit_dict[visit], TNFA5_visit_dict[visit], TNFA6_visit_dict[visit])

    # Display the results
    print("ANOVA Statistic:", statistic)
    print("P-value:", p_value)

    # Check the significance level (e.g., 0.05)
    alpha = 0.05
    if p_value < alpha:
        print("Reject the null hypothesis. There are significant differences between groups.")
    else:
        print("Fail to reject the null hypothesis. There are no significant differences between groups.")
# Out:
# ANOVA Statistic: 1.5083552666894975
# P-value: 0.2407331065961959
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 11.750980071370849
# P-value: 0.0002524986023124872
# Reject the null hypothesis. There are significant differences between groups.
# ANOVA Statistic: 6.6296480095031125
# P-value: 0.005101749847196078
# Reject the null hypothesis. There are significant differences between groups.
# ANOVA Statistic: 0.12917794144051314
# P-value: 0.8795104941397541
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 1.434347484416461
# P-value: 0.2565077855130348
# Fail to reject the null hypothesis. There are no significant differences between groups.

# %%
IGG4_visit_dict = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG4_visit_dict[visit] = lomas_IGG_4[
        lomas_IGG_4.VisitLabel == visit
    ].ValueNum
    
IGG5_visit_dict = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG5_visit_dict[visit] = lomas_IGG_5[
        lomas_IGG_5.VisitLabel == visit
    ].ValueNum
    
IGG6_visit_dict = {}
for visit in lomas_IGG.VisitLabel.unique():
    IGG6_visit_dict[visit] = lomas_IGG_6[
        lomas_IGG_6.VisitLabel == visit
    ].ValueNum

CRP4_visit_dict = {}
for visit in lomas_CRP.VisitLabel.unique():
    CRP4_visit_dict[visit] = lomas_CRP_4[
        lomas_CRP_4.VisitLabel == visit
    ].ValueNum
    
CRP5_visit_dict = {}
for visit in lomas_CRP.VisitLabel.unique():
    CRP5_visit_dict[visit] = lomas_CRP_5[
        lomas_CRP_5.VisitLabel == visit
    ].ValueNum
    
CRP6_visit_dict = {}
for visit in lomas_CRP.VisitLabel.unique():
    CRP6_visit_dict[visit] = lomas_CRP_6[
        lomas_CRP_6.VisitLabel == visit
    ].ValueNum
    
# Cytokine4_visit_dict = {}
# for visit in lomas_Cytokine.VisitLabel.unique():
#     Cytokine4_visit_dict[visit] = lomas_Cytokine_4[
#         lomas_Cytokine_4.VisitLabel == visit
#     ].ValueNum
    
# Cytokine5_visit_dict = {}
# for visit in lomas_Cytokine.VisitLabel.unique():
#     Cytokine5_visit_dict[visit] = lomas_Cytokine_5[
#         lomas_Cytokine_5.VisitLabel == visit
#     ].ValueNum
    
# Cytokine6_visit_dict = {}
# for visit in lomas_Cytokine.VisitLabel.unique():
#     Cytokine6_visit_dict[visit] = lomas_Cytokine_6[
#         lomas_Cytokine_6.VisitLabel == visit
#     ].ValueNum
#print(Cytokine_visit_dict)

# length_of_value = len(Cytokine_visit_dict['Screening'])
# print(length_of_value)
# print(len(lomas_Cytokine_4))

# Perform 5 one-way ANOVAs 
        
for visit in lomas_IGA.VisitLabel.unique():
    statistic, p_value = stats.f_oneway(IGA4_visit_dict[visit], IGA5_visit_dict[visit], IGA6_visit_dict[visit])

    # Display the results
    print("ANOVA Statistic:", statistic)
    print("P-value:", p_value)

    # Check the significance level (e.g., 0.05)
    alpha = 0.05
    if p_value < alpha:
        print("Reject the null hypothesis. There are significant differences between groups.")
    else:
        print("Fail to reject the null hypothesis. There are no significant differences between groups.")
# Out:
# ANOVA Statistic: 0.4993382288708661
# P-value: 0.612234737904815
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 0.33695791452943064
# P-value: 0.7168982238010395
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 0.38570082417263385
# P-value: 0.6839504108705958
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 1.522274487173352
# P-value: 0.2370354188790943
# Fail to reject the null hypothesis. There are no significant differences between groups.
# ANOVA Statistic: 0.2006482657044743
# P-value: 0.8194091259135226
# Fail to reject the null hypothesis. There are no significant differences between groups.

# %%
stat_df = pd.DataFrame()

#need to group by arm and visit and type
lomas_IGG_4_Screening = lomas_IGG_4[lomas_IGG_4.treatment_arm == "Arm 4"].reset_index()
lomas_IGG_5_Screening = lomas_IGG_5[lomas_IGG_5.treatment_arm == "Arm 5"].reset_index()
lomas_IGG_6_Screening = lomas_IGG_6[lomas_IGG_6.treatment_arm == "Arm 6"].reset_index()
# Out:
# 0     1487.0
# 1     1327.0
# 2     1301.0
# 3     1374.0
# 4     1390.0
# 5     1192.0
# 6     1167.0
# 7     1149.0
# 8     1223.0
# 9     1282.0
# 10    1282.0
# 11    1208.0
# 12    1274.0
# 13    1255.0
# 14    1250.0
# 15    1379.0
# 16    1358.0
# 17    1321.0
# 18    1347.0
# 19    1298.0
# 20    1209.0
# 21    1170.0
# 22    1134.0
# 23    1142.0
# 24    1278.0
# 25    1498.0
# 26    1525.0
# 27    1480.0
# 28    1434.0
# 29    1233.0
# 30    1226.0
# 31    1162.0
# 32    1218.0
# 33    1229.0
# 34     745.0
# 35    1007.0
# 36    1045.0
# 37     966.0
# 38    1078.0
# 39    1057.0
# 40    1022.0
# 41    1058.0
# 42     983.0
# 43     993.0
# 44    1193.0
# 45    1125.0
# 46    1261.0
# 47    1200.0
# 48    1185.0
# 49    1003.0
# 50    1014.0
# 51    1011.0
# 52    1006.0
# 53    1025.0
# Name: ValueNum, dtype: float64
